# %% [markdown]
# <h1 align="center" style="color:#96d9f0;">Computational Intelligence for
# Optimization - Project</h1>
# <h3 align="center" style="color:#96d9f0;">Group AW - Wedding Seating Optimization</h3>
#
# ---
#
# ### <span style="color:#96d9f0;">Group Members</span>
#
# <table>
#   <thead style="color:#96d9f0;">
#     <tr>
#       <th>Name</th>
#       <th>Email</th>
#       <th>Student ID</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Afonso Dias</td>
#       <td>20211540@novaims.unl.pt</td>
#       <td>20211540</td>
#     </tr>
#     <tr>
#       <td>Isabel Duarte</td>
#       <td>20240545@novaims.unl.pt</td>
#       <td>20240545</td>
#     </tr>
#     <tr>
#       <td>Pedro Campino</td>
#       <td>20240537@novaims.unl.pt</td>
#       <td>20240537</td>
#     </tr>
#     <tr>
#       <td>Rita Matos</td>
#       <td>20211642@novaims.unl.pt</td>
#       <td>20211642</td>
#     </tr>
#   </tbody>
# </table>

# %%
import sys
sys.path.append('..')

# %%
import random
from copy import deepcopy
from library.solution import Solution
import csv
import os
import pandas as pd
import numpy as np
from itertools import combinations

# %%
#future improvements: test random fitnesses to set a baseline average to compare our results

# %%
#No swap mutation within the same table

# %%
# Import csv
import csv
import os
import pandas as pd

relations_matrix = np.loadtxt('seating_data.csv', delimiter=',', skiprows=1)
relations_matrix = relations_matrix[ : , 1:]

#relationship_matrix = pd.read_csv('seating_data.csv')
#relationship_matrix.drop(columns='idx', inplace=True)

relations_matrix
# Out:
# array([[   0., 5000.,    0., ...,    0.,    0.,    0.],
#        [5000.,    0.,  700., ...,    0.,    0.,    0.],
#        [   0.,  700.,    0., ...,    0.,    0.,    0.],
#        ...,
#        [   0.,    0.,    0., ...,    0.,  700.,  700.],
#        [   0.,    0.,    0., ...,  700.,    0.,  900.],
#        [   0.,    0.,    0., ...,  700.,  900.,    0.]])

# %%
class WSSolution(Solution):
    def __init__(self, repr=None, relations_matrix=relations_matrix, nr_of_tables=8):
        self.relations_matrix = relations_matrix
        self.nr_of_tables = nr_of_tables
        self.table_capacity = len(relations_matrix) // nr_of_tables
        super().__init__(repr=repr)

    def random_initial_representation(self):
        tables = []
        left_idxs = [idx for idx in range(len(self.relations_matrix))]
        for i in range(self.nr_of_tables):
            tables.append([])
            for j in range(self.table_capacity):
                idx = random.choice(left_idxs)
                left_idxs.remove(idx)
                # Check if idx is already in a table
                while any(idx in table for table in tables):
                    idx = random.randint(0, len(self.relations_matrix) - 1)
                tables[i].append(idx)
        
        return tables

    
    
    def fitness(self):
        total_happiness = 0
        for i, row in enumerate(self.repr):
            table_happiness = 0
            combs = list(combinations(row, 2))
            pair_scores = [self.relations_matrix[a, b] for a, b in combs]
            table_happiness = sum(s for s in pair_scores)
            total_happiness += table_happiness
        return total_happiness

# %%
solution = WSSolution()

# %%
solution.fitness()
# Out:
# np.float64(12800.0)

# %%
solution.repr
# Out:
# [[8, 50, 32, 55, 62, 15, 27, 16],
#  [0, 34, 10, 30, 44, 4, 26, 40],
#  [33, 54, 14, 52, 35, 46, 21, 25],
#  [59, 9, 53, 38, 56, 57, 5, 23],
#  [61, 2, 29, 24, 63, 11, 42, 19],
#  [45, 28, 58, 48, 6, 20, 51, 39],
#  [47, 7, 12, 13, 60, 18, 17, 31],
#  [22, 43, 36, 49, 3, 1, 37, 41]]

# %%
def genetic_algorithm(
    initial_population,
    max_gen,
    selection_algorithm,
    crossover_operator,
    mutation_operator,
    xo_prob=0.9,
    mut_prob=0.1,
    elitism=True,
    maximization=True,
    verbose=False,
):
    population = initial_population
    best_individual = None

    for gen in range(max_gen):
        if verbose:
            print(f"\nGeneration {gen + 1}")

        # Evaluate fitness
        fitnesses = [ind.fitness() for ind in population]

        # Get elite
        if elitism:
            elite = max(population, key=lambda ind: ind.fitness()) if maximization else min(population, key=lambda ind: ind.fitness())

        # Generate new population
        new_population = []

        while len(new_population) < len(population):
            # Selection
            parent1 = selection_algorithm(population)
            parent2 = selection_algorithm(population)

            # Crossover
            if random.random() < xo_prob:
                offspring1, offspring2 = crossover_operator(parent1, parent2)
            else:
                offspring1, offspring2 = deepcopy(parent1), deepcopy(parent2)

            # Mutation
            mutation_operator(offspring1, mut_prob)
            mutation_operator(offspring2, mut_prob)

            new_population.extend([offspring1, offspring2])

        # Replace worst with elite
        if elitism:
            new_population[random.randint(0, len(new_population) - 1)] = elite

        population = new_population[:len(population)]

        # Store best
        candidate = max(population, key=lambda ind: ind.fitness()) if maximization else min(population, key=lambda ind: ind.fitness())
        if best_individual is None or (
            (maximization and candidate.fitness() > best_individual.fitness()) or
            (not maximization and candidate.fitness() < best_individual.fitness())
        ):
            best_individual = deepcopy(candidate)

        if verbose:
            print(f"Best fitness so far: {best_individual.fitness()}")

    return best_individual

def tournament_selection(population, k=3):
    competitors = random.sample(population, k)
    return max(competitors, key=lambda ind: ind.fitness())

def mutate(solution, mut_prob):
    if random.random() < mut_prob:
        tables = solution.repr
        if len(tables) < 2:
            return

        # Pick two random tables
        t1, t2 = random.sample(range(len(tables)), 2)
        if not tables[t1] or not tables[t2]:
            return

        # Swap one person from each
        i1 = random.randint(0, len(tables[t1]) - 1)
        i2 = random.randint(0, len(tables[t2]) - 1)
        tables[t1][i1], tables[t2][i2] = tables[t2][i2], tables[t1][i1]

def crossover(parent1, parent2):
    p1_tables = deepcopy(parent1.repr)
    p2_tables = deepcopy(parent2.repr)
    child1_repr = p1_tables[:len(p1_tables)//2] + p2_tables[len(p2_tables)//2:]
    child2_repr = p2_tables[:len(p2_tables)//2] + p1_tables[len(p1_tables)//2:]

    # Flatten, remove duplicates, fill missing for child1
    def fix_child(tables, num_people, num_tables, cap):
        flat = [p for table in tables for p in table]
        seen = set()
        cleaned = [p for p in flat if not (p in seen or seen.add(p))]
        missing = [i for i in range(num_people) if i not in cleaned]
        cleaned.extend(missing)
        return [cleaned[i*cap:(i+1)*cap] for i in range(num_tables)]

    num_people = len(parent1.relations_matrix)
    cap = parent1.table_capacity
    num_tables = parent1.nr_of_tables

    child1 = WSSolution(relations_matrix=parent1.relations_matrix)
    child2 = WSSolution(relations_matrix=parent1.relations_matrix)
    child1.repr = fix_child(child1_repr, num_people, num_tables, cap)
    child2.repr = fix_child(child2_repr, num_people, num_tables, cap)
    return child1, child2

# %%
# Create initial population
population = [WSSolution(relations_matrix=relations_matrix) for _ in range(50)]
for sol in population:
    sol.repr = sol.random_initial_representation()

# Run GA
best = genetic_algorithm(
    initial_population=population,
    max_gen=2000,
    selection_algorithm=tournament_selection,
    crossover_operator=crossover,
    mutation_operator=mutate,
    xo_prob=0.8,
    mut_prob=0.2,
    elitism=True,
    maximization=True,
    verbose=True,
)

print("Best fitness found:", best.fitness())
# Out:
# Generation 1
# Best fitness so far: 25800.0
#
# Generation 2
# Best fitness so far: 25800.0
#
# Generation 3
# Best fitness so far: 25800.0
#
# Generation 4
# Best fitness so far: 28700.0
#
# Generation 5
# Best fitness so far: 32100.0
#
# Generation 6
# Best fitness so far: 32100.0
#
# Generation 7
# Best fitness so far: 33000.0
#
# Generation 8
# Best fitness so far: 33000.0
#
# Generation 9
# Best fitness so far: 33000.0
#
# Generation 10
# Best fitness so far: 34200.0
#
# Generation 11
# Best fitness so far: 34200.0
#
# Generation 12
# Best fitness so far: 34200.0
#
# Generation 13
# Best fitness so far: 35000.0
#
# Generation 14
# Best fitness so far: 35000.0
#
# Generation 15
# Best fitness so far: 36200.0
#
# Generation 16
# Best fitness so far: 36200.0
#
# Generation 17
# Best fitness so far: 36700.0
#
# Generation 18
# Best fitness so far: 36700.0
#
# Generation 19
# Best fitness so far: 36800.0
#
# Generation 20
# Best fitness so far: 37100.0
#
# Generation 21
# Best fitness so far: 38700.0
#
# Generation 22
# Best fitness so far: 38700.0
#
# Generation 23
# Best fitness so far: 38800.0
#
# Generation 24
# Best fitness so far: 38800.0
#
# Generation 25
# Best fitness so far: 38800.0
#
# Generation 26
# Best fitness so far: 38800.0
#
# Generation 27
# Best fitness so far: 38900.0
#
# Generation 28
# Best fitness so far: 38900.0
#
# Generation 29
# Best fitness so far: 40400.0
#
# Generation 30
# Best fitness so far: 40700.0
#
# Generation 31
# Best fitness so far: 41600.0
#
# Generation 32
# Best fitness so far: 41600.0
#
# Generation 33
# Best fitness so far: 43400.0
#
# Generation 34
# Best fitness so far: 43400.0
#
# Generation 35
# Best fitness so far: 43700.0
#
# Generation 36
# Best fitness so far: 43700.0
#
# Generation 37
# Best fitness so far: 43700.0
#
# Generation 38
# Best fitness so far: 43700.0
#
# Generation 39
# Best fitness so far: 43700.0
#
# Generation 40
# Best fitness so far: 44200.0
#
# Generation 41
# Best fitness so far: 44200.0
#
# Generation 42
# Best fitness so far: 44200.0
#
# Generation 43
# Best fitness so far: 44200.0
#
# Generation 44
# Best fitness so far: 44200.0
#
# Generation 45
# Best fitness so far: 44200.0
#
# Generation 46
# Best fitness so far: 44200.0
#
# Generation 47
# Best fitness so far: 44200.0
#
# Generation 48
# Best fitness so far: 44200.0
#
# Generation 49
# Best fitness so far: 44200.0
#
# Generation 50
# Best fitness so far: 44200.0
#
# Generation 51
# Best fitness so far: 44200.0
#
# Generation 52
# Best fitness so far: 44200.0
#
# Generation 53
# Best fitness so far: 44200.0
#
# Generation 54
# Best fitness so far: 44200.0
#
# Generation 55
# Best fitness so far: 44200.0
#
# Generation 56
# Best fitness so far: 45200.0
#
# Generation 57
# Best fitness so far: 45200.0
#
# Generation 58
# Best fitness so far: 45200.0
#
# Generation 59
# Best fitness so far: 45300.0
#
# Generation 60
# Best fitness so far: 45300.0
#
# Generation 61
# Best fitness so far: 45900.0
#
# Generation 62
# Best fitness so far: 45900.0
#
# Generation 63
# Best fitness so far: 45900.0
#
# Generation 64
# Best fitness so far: 45900.0
#
# Generation 65
# Best fitness so far: 46200.0
#
# Generation 66
# Best fitness so far: 46200.0
#
# Generation 67
# Best fitness so far: 46200.0
#
# Generation 68
# Best fitness so far: 46200.0
#
# Generation 69
# Best fitness so far: 46300.0
#
# Generation 70
# Best fitness so far: 46300.0
#
# Generation 71
# Best fitness so far: 48300.0
#
# Generation 72
# Best fitness so far: 48300.0
#
# Generation 73
# Best fitness so far: 48300.0
#
# Generation 74
# Best fitness so far: 48300.0
#
# Generation 75
# Best fitness so far: 48800.0
#
# Generation 76
# Best fitness so far: 50100.0
#
# Generation 77
# Best fitness so far: 50400.0
#
# Generation 78
# Best fitness so far: 50400.0
#
# Generation 79
# Best fitness so far: 50400.0
#
# Generation 80
# Best fitness so far: 50400.0
#
# Generation 81
# Best fitness so far: 50400.0
#
# Generation 82
# Best fitness so far: 50400.0
#
# Generation 83
# Best fitness so far: 50400.0
#
# Generation 84
# Best fitness so far: 52300.0
#
# Generation 85
# Best fitness so far: 52300.0
#
# Generation 86
# Best fitness so far: 52300.0
#
# Generation 87
# Best fitness so far: 52300.0
#
# Generation 88
# Best fitness so far: 52300.0
#
# Generation 89
# Best fitness so far: 52300.0
#
# Generation 90
# Best fitness so far: 52300.0
#
# Generation 91
# Best fitness so far: 52300.0
#
# Generation 92
# Best fitness so far: 52300.0
#
# Generation 93
# Best fitness so far: 53300.0
#
# Generation 94
# Best fitness so far: 53300.0
#
# Generation 95
# Best fitness so far: 53300.0
#
# Generation 96
# Best fitness so far: 54000.0
#
# Generation 97
# Best fitness so far: 54000.0
#
# Generation 98
# Best fitness so far: 54100.0
#
# Generation 99
# Best fitness so far: 54100.0
#
# Generation 100
# Best fitness so far: 54600.0
#
# Generation 101
# Best fitness so far: 54600.0
#
# Generation 102
# Best fitness so far: 54600.0
#
# Generation 103
# Best fitness so far: 57600.0
#
# Generation 104
# Best fitness so far: 57600.0
#
# Generation 105
# Best fitness so far: 57600.0
#
# Generation 106
# Best fitness so far: 57900.0
#
# Generation 107
# Best fitness so far: 58300.0
#
# Generation 108
# Best fitness so far: 58300.0
#
# Generation 109
# Best fitness so far: 58300.0
#
# Generation 110
# Best fitness so far: 58300.0
#
# Generation 111
# Best fitness so far: 58300.0
#
# Generation 112
# Best fitness so far: 59100.0
#
# Generation 113
# Best fitness so far: 59100.0
#
# Generation 114
# Best fitness so far: 59100.0
#
# Generation 115
# Best fitness so far: 59100.0
#
# Generation 116
# Best fitness so far: 59100.0
#
# Generation 117
# Best fitness so far: 59100.0
#
# Generation 118
# Best fitness so far: 59100.0
# Best fitness so far: 68300.0
#
# Generation 248
# Best fitness so far: 68300.0
#
# Generation 249
# Best fitness so far: 68300.0
#
# Generation 250
# Best fitness so far: 68300.0
#
# Generation 251
# Best fitness so far: 68300.0
#
# Generation 252
# Best fitness so far: 68300.0
#
# Generation 253
# Best fitness so far: 68300.0
#
# Generation 254
# Best fitness so far: 68300.0
#
# Generation 255
# Best fitness so far: 68300.0
#
# Generation 256
# Best fitness so far: 68300.0
#
# Generation 257
# Best fitness so far: 68300.0
#
# Generation 258
# Best fitness so far: 68300.0
#
# Generation 259
# Best fitness so far: 68300.0
#
# Generation 260
# Best fitness so far: 68300.0
#
# Generation 261
# Best fitness so far: 68300.0
#
# Generation 262
# Best fitness so far: 68300.0
#
# Generation 263
# Best fitness so far: 68300.0
#
# Generation 264
# Best fitness so far: 68300.0
#
# Generation 265
# Best fitness so far: 68300.0
#
# Generation 266
# Best fitness so far: 68300.0
#
# Generation 267
# Best fitness so far: 68300.0
#
# Generation 268
# Best fitness so far: 68300.0
#
# Generation 269
# Best fitness so far: 68300.0
#
# Generation 270
# Best fitness so far: 68300.0
#
# Generation 271
# Best fitness so far: 68300.0
#
# Generation 272
# Best fitness so far: 68300.0
#
# Generation 273
# Best fitness so far: 68300.0
#
# Generation 274
# Best fitness so far: 68300.0
#
# Generation 275
# Best fitness so far: 68300.0
#
# Generation 276
# Best fitness so far: 68300.0
#
# Generation 277
# Best fitness so far: 68300.0
#
# Generation 278
# Best fitness so far: 68300.0
#
# Generation 279
# Best fitness so far: 68300.0
#
# Generation 280
# Best fitness so far: 68300.0
#
# Generation 281
# Best fitness so far: 68300.0
#
# Generation 282
# Best fitness so far: 68300.0
#
# Generation 283
# Best fitness so far: 68300.0
#
# Generation 284
# Best fitness so far: 68300.0
#
# Generation 285
# Best fitness so far: 68400.0
#
# Generation 286
# Best fitness so far: 68400.0
#
# Generation 287
# Best fitness so far: 68400.0
#
# Generation 288
# Best fitness so far: 68400.0
#
# Generation 289
# Best fitness so far: 68400.0
#
# Generation 290
# Best fitness so far: 68400.0
#
# Generation 291
# Best fitness so far: 68400.0
#
# Generation 292
# Best fitness so far: 68400.0
#
# Generation 293
# Best fitness so far: 68400.0
#
# Generation 294
# Best fitness so far: 68400.0
#
# Generation 295
# Best fitness so far: 68400.0
#
# Generation 296
# Best fitness so far: 68400.0
#
# Generation 297
# Best fitness so far: 68400.0
#
# Generation 298
# Best fitness so far: 68400.0
#
# Generation 299
# Best fitness so far: 68400.0
#
# Generation 300
# Best fitness so far: 68400.0
#
# Generation 301
# Best fitness so far: 68600.0
#
# Generation 302
# Best fitness so far: 68600.0
#
# Generation 303
# Best fitness so far: 68600.0
#
# Generation 304
# Best fitness so far: 68600.0
#
# Generation 305
# Best fitness so far: 68600.0
#
# Generation 306
# Best fitness so far: 68600.0
#
# Generation 307
# Best fitness so far: 68600.0
#
# Generation 308
# Best fitness so far: 68600.0
#
# Generation 309
# Best fitness so far: 68600.0
#
# Generation 310
# Best fitness so far: 68600.0
#
# Generation 311
# Best fitness so far: 68700.0
# Generation 376
# Best fitness so far: 71100.0
#
# Generation 377
# Best fitness so far: 71100.0
#
# Generation 378
# Best fitness so far: 71100.0
#
# Generation 379
# Best fitness so far: 71100.0
#
# Generation 380
# Best fitness so far: 71100.0
#
# Generation 381
# Best fitness so far: 71100.0
#
# Generation 382
# Best fitness so far: 71100.0
#
# Generation 383
# Best fitness so far: 71100.0
#
# Generation 384
# Best fitness so far: 71100.0
#
# Generation 385
# Best fitness so far: 71100.0
#
# Generation 386
# Best fitness so far: 71300.0
#
# Generation 387
# Best fitness so far: 71300.0
#
# Generation 388
# Best fitness so far: 71300.0
#
# Generation 389
# Best fitness so far: 71300.0
#
# Generation 390
# Best fitness so far: 71300.0
#
# Generation 391
# Best fitness so far: 71300.0
#
# Generation 392
# Best fitness so far: 71300.0
#
# Generation 393
# Best fitness so far: 71300.0
#
# Generation 394
# Best fitness so far: 71300.0
#
# Generation 395
# Best fitness so far: 71300.0
#
# Generation 396
# Best fitness so far: 71300.0
#
# Generation 397
# Best fitness so far: 71300.0
#
# Generation 398
# Best fitness so far: 71300.0
#
# Generation 399
# Best fitness so far: 71300.0
#
# Generation 400
# Best fitness so far: 71300.0
#
# Generation 401
# Best fitness so far: 71300.0
#
# Generation 402
# Best fitness so far: 71300.0
#
# Generation 403
# Best fitness so far: 71300.0
#
# Generation 404
# Best fitness so far: 71300.0
#
# Generation 405
# Best fitness so far: 71300.0
#
# Generation 406
# Best fitness so far: 71300.0
#
# Generation 407
# Best fitness so far: 71300.0
#
# Generation 408
# Best fitness so far: 71300.0
#
# Generation 409
# Best fitness so far: 71300.0
#
# Generation 410
# Best fitness so far: 71300.0
#
# Generation 411
# Best fitness so far: 71300.0
#
# Generation 412
# Best fitness so far: 71300.0
#
# Generation 413
# Best fitness so far: 71300.0
#
# Generation 414
# Best fitness so far: 71300.0
#
# Generation 415
# Best fitness so far: 71300.0
#
# Generation 416
# Best fitness so far: 71300.0
#
# Generation 417
# Best fitness so far: 71300.0
#
# Generation 418
# Best fitness so far: 71300.0
#
# Generation 419
# Best fitness so far: 71300.0
#
# Generation 420
# Best fitness so far: 72500.0
#
# Generation 421
# Best fitness so far: 72500.0
#
# Generation 422
# Best fitness so far: 72500.0
#
# Generation 423
# Best fitness so far: 72500.0
#
# Generation 424
# Best fitness so far: 72500.0
#
# Generation 425
# Best fitness so far: 72500.0
#
# Generation 426
# Best fitness so far: 72500.0
#
# Generation 427
# Best fitness so far: 72500.0
#
# Generation 428
# Best fitness so far: 72500.0
#
# Generation 429
# Best fitness so far: 72500.0
#
# Generation 430
# Best fitness so far: 72500.0
#
# Generation 431
# Best fitness so far: 72500.0
#
# Generation 432
# Best fitness so far: 72500.0
#
# Generation 433
# Best fitness so far: 72500.0
#
# Generation 434
# Best fitness so far: 72500.0
#
# Generation 435
# Best fitness so far: 72500.0
#
# Generation 436
# Best fitness so far: 72500.0
#
# Generation 437
# Best fitness so far: 72500.0
#
# Generation 438
# Best fitness so far: 72500.0
#
# Generation 439
# Best fitness so far: 72500.0
#
# Generation 440
#
# Generation 505
# Best fitness so far: 74600.0
#
# Generation 506
# Best fitness so far: 74600.0
#
# Generation 507
# Best fitness so far: 74600.0
#
# Generation 508
# Best fitness so far: 74600.0
#
# Generation 509
# Best fitness so far: 74600.0
#
# Generation 510
# Best fitness so far: 74600.0
#
# Generation 511
# Best fitness so far: 74600.0
#
# Generation 512
# Best fitness so far: 74600.0
#
# Generation 513
# Best fitness so far: 74600.0
#
# Generation 514
# Best fitness so far: 74600.0
#
# Generation 515
# Best fitness so far: 74600.0
#
# Generation 516
# Best fitness so far: 74600.0
#
# Generation 517
# Best fitness so far: 74700.0
#
# Generation 518
# Best fitness so far: 74700.0
#
# Generation 519
# Best fitness so far: 74700.0
#
# Generation 520
# Best fitness so far: 74700.0
#
# Generation 521
# Best fitness so far: 74700.0
#
# Generation 522
# Best fitness so far: 74700.0
#
# Generation 523
# Best fitness so far: 74700.0
#
# Generation 524
# Best fitness so far: 74700.0
#
# Generation 525
# Best fitness so far: 74700.0
#
# Generation 526
# Best fitness so far: 74700.0
#
# Generation 527
# Best fitness so far: 74700.0
#
# Generation 528
# Best fitness so far: 75600.0
#
# Generation 529
# Best fitness so far: 75600.0
#
# Generation 530
# Best fitness so far: 75600.0
#
# Generation 531
# Best fitness so far: 75600.0
#
# Generation 532
# Best fitness so far: 75600.0
#
# Generation 533
# Best fitness so far: 75600.0
#
# Generation 534
# Best fitness so far: 75600.0
#
# Generation 535
# Best fitness so far: 75600.0
#
# Generation 536
# Best fitness so far: 75600.0
#
# Generation 537
# Best fitness so far: 75600.0
#
# Generation 538
# Best fitness so far: 75600.0
#
# Generation 539
# Best fitness so far: 75600.0
#
# Generation 540
# Best fitness so far: 75600.0
#
# Generation 541
# Best fitness so far: 75600.0
#
# Generation 542
# Best fitness so far: 75600.0
#
# Generation 543
# Best fitness so far: 75600.0
#
# Generation 544
# Best fitness so far: 75600.0
#
# Generation 545
# Best fitness so far: 75600.0
#
# Generation 546
# Best fitness so far: 75600.0
#
# Generation 547
# Best fitness so far: 75600.0
#
# Generation 548
# Best fitness so far: 75600.0
#
# Generation 549
# Best fitness so far: 75600.0
#
# Generation 550
# Best fitness so far: 75600.0
#
# Generation 551
# Best fitness so far: 75600.0
#
# Generation 552
# Best fitness so far: 75600.0
#
# Generation 553
# Best fitness so far: 75600.0
#
# Generation 554
# Best fitness so far: 75600.0
#
# Generation 555
# Best fitness so far: 75600.0
#
# Generation 556
# Best fitness so far: 75600.0
#
# Generation 557
# Best fitness so far: 75600.0
#
# Generation 558
# Best fitness so far: 75600.0
#
# Generation 559
# Best fitness so far: 75600.0
#
# Generation 560
# Best fitness so far: 75600.0
#
# Generation 561
# Best fitness so far: 75600.0
#
# Generation 562
# Best fitness so far: 75600.0
#
# Generation 563
# Best fitness so far: 75600.0
#
# Generation 564
# Best fitness so far: 75600.0
#
# Generation 565
# Best fitness so far: 75600.0
#
# Generation 566
# Best fitness so far: 75600.0
#
# Generation 567
# Best fitness so far: 75600.0
#
# Generation 568
# Best fitness so far: 75600.0
#
# Generation 569
# Best fitness so far: 75600.0
#
# Generation 570
# Best fitness so far: 75600.0
#
# Generation 571
# Best fitness so far: 75600.0
#
# Generation 572
# Best fitness so far: 75600.0
#
# Generation 573
# Best fitness so far: 75600.0
#
# Generation 574
# Best fitness so far: 75600.0
#
# Generation 575
# Best fitness so far: 75600.0
#
# Generation 576
# Best fitness so far: 75600.0
#
# Generation 577
# Best fitness so far: 75600.0
#
# Generation 578
# Best fitness so far: 75600.0
#
# Generation 579
# Best fitness so far: 75600.0
#
# Generation 580
# Best fitness so far: 75600.0
#
# Generation 581
# Best fitness so far: 75600.0
#
# Generation 582
# Best fitness so far: 75600.0
#
# Generation 583
# Best fitness so far: 75600.0
#
# Generation 584
# Best fitness so far: 75600.0
#
# Generation 585
# Best fitness so far: 75600.0
#
# Generation 586
# Best fitness so far: 75600.0
#
# Generation 587
# Best fitness so far: 75600.0
#
# Generation 588
# Best fitness so far: 75600.0
#
# Generation 589
# Best fitness so far: 75600.0
#
# Generation 590
# Best fitness so far: 75600.0
#
# Generation 591
# Best fitness so far: 75600.0
#
# Generation 592
# Best fitness so far: 75600.0
#
# Generation 593
# Best fitness so far: 75600.0
#
# Generation 594
# Best fitness so far: 75600.0
#
# Generation 595
# Best fitness so far: 75600.0
#
# Generation 596
# Best fitness so far: 75600.0
#
# Generation 597
# Best fitness so far: 75600.0
#
# Generation 598
# Best fitness so far: 75600.0
#
# Generation 599
# Best fitness so far: 75600.0
#
# Generation 600
# Best fitness so far: 75600.0
#
# Generation 601
# Best fitness so far: 75600.0
#
# Generation 602
# Best fitness so far: 75600.0
#
# Generation 603
# Best fitness so far: 75600.0
#
# Generation 604
# Best fitness so far: 75600.0
#
# Generation 605
# Best fitness so far: 75600.0
#
# Generation 606
# Best fitness so far: 75600.0
#
# Generation 607
# Best fitness so far: 75600.0
#
# Generation 608
# Best fitness so far: 75600.0
#
# Generation 609
# Best fitness so far: 75600.0
#
# Generation 610
# Best fitness so far: 75600.0
#
# Generation 611
# Best fitness so far: 75600.0
#
# Generation 612
# Best fitness so far: 75600.0
#
# Generation 613
# Best fitness so far: 75600.0
#
# Generation 614
# Best fitness so far: 75600.0
#
# Generation 615
# Best fitness so far: 75600.0
#
# Generation 616
# Best fitness so far: 75600.0
#
# Generation 617
# Best fitness so far: 75600.0
#
# Generation 618
# Best fitness so far: 75600.0
#
# Generation 619
# Best fitness so far: 75600.0
#
# Generation 620
# Best fitness so far: 75600.0
#
# Generation 621
# Best fitness so far: 75600.0
#
# Generation 622
# Best fitness so far: 75600.0
#
# Generation 623
# Best fitness so far: 75600.0
#
# Generation 624
# Best fitness so far: 75600.0
#
# Generation 625
# Best fitness so far: 75600.0
#
# Generation 626
# Best fitness so far: 75600.0
#
# Generation 627
# Best fitness so far: 75600.0
#
# Generation 628
# Best fitness so far: 75600.0
#
# Generation 629
# Best fitness so far: 75600.0
#
# Generation 630
# Best fitness so far: 75600.0
#
# Generation 631
# Best fitness so far: 75600.0
#
# Generation 632
# Best fitness so far: 75600.0
#
# Generation 633
# Best fitness so far: 75600.0
#
# Generation 634
# Best fitness so far: 75600.0
#
# Generation 635
# Best fitness so far: 75600.0
#
# Generation 636
# Best fitness so far: 75600.0
#
# Generation 637
# Best fitness so far: 75600.0
#
# Generation 638
# Best fitness so far: 75600.0
#
# Generation 639
# Best fitness so far: 75600.0
#
# Generation 640
# Best fitness so far: 75600.0
#
# Generation 641
# Best fitness so far: 75600.0
#
# Generation 642
# Best fitness so far: 75600.0
#
# Generation 643
# Best fitness so far: 75600.0
#
# Generation 644
# Best fitness so far: 75600.0
#
# Generation 645
# Best fitness so far: 75600.0
#
# Generation 646
# Best fitness so far: 75600.0
#
# Generation 647
# Best fitness so far: 75600.0
#
# Generation 648
# Best fitness so far: 75600.0
#
# Generation 649
# Best fitness so far: 75600.0
#
# Generation 650
# Best fitness so far: 75600.0
#
# Generation 651
# Best fitness so far: 75600.0
#
# Generation 652
# Best fitness so far: 75600.0
#
# Generation 653
# Best fitness so far: 75600.0
#
# Generation 654
# Best fitness so far: 75600.0
#
# Generation 655
# Best fitness so far: 75600.0
#
# Generation 656
# Best fitness so far: 75600.0
#
# Generation 657
# Best fitness so far: 75600.0
#
# Generation 658
# Best fitness so far: 75600.0
#
# Generation 659
# Best fitness so far: 75600.0
#
# Generation 660
# Best fitness so far: 75600.0
#
# Generation 661
# Best fitness so far: 75600.0
#
# Generation 662
# Best fitness so far: 75600.0
#
# Generation 663
# Best fitness so far: 75600.0
#
# Generation 664
# Best fitness so far: 75600.0
#
# Generation 665
# Best fitness so far: 75600.0
#
# Generation 666
# Best fitness so far: 75600.0
#
# Generation 667
# Best fitness so far: 75600.0
#
# Generation 668
# Best fitness so far: 75600.0
#
# Generation 669
# Best fitness so far: 75600.0
#
# Generation 670
# Best fitness so far: 75600.0
#
# Generation 671
# Best fitness so far: 75600.0
#
# Generation 672
# Best fitness so far: 75600.0
#
# Generation 673
# Best fitness so far: 75600.0
#
# Generation 674
# Best fitness so far: 75600.0
#
# Generation 675
# Best fitness so far: 75600.0
#
# Generation 676
# Best fitness so far: 75600.0
#
# Generation 677
# Best fitness so far: 75600.0
#
# Generation 678
# Best fitness so far: 75600.0
#
# Generation 679
# Best fitness so far: 75600.0
#
# Generation 680
# Best fitness so far: 75600.0
#
# Generation 681
# Best fitness so far: 75600.0
#
# Generation 682
# Best fitness so far: 75600.0
#
# Generation 683
# Best fitness so far: 75600.0
#
# Generation 684
# Best fitness so far: 75600.0
#
# Generation 685
# Best fitness so far: 75600.0
#
# Generation 686
# Best fitness so far: 75600.0
#
# Generation 687
# Best fitness so far: 75600.0
#
# Generation 688
# Best fitness so far: 75600.0
#
# Generation 689
# Best fitness so far: 75600.0
#
# Generation 690
# Best fitness so far: 75600.0
#
# Generation 691
# Best fitness so far: 75600.0
#
# Generation 692
# Best fitness so far: 75600.0
#
# Generation 693
# Best fitness so far: 75600.0
#
# Generation 694
# Best fitness so far: 75600.0
#
# Generation 695
# Best fitness so far: 75600.0
#
# Generation 696
# Best fitness so far: 75600.0
#
# Generation 697
# Best fitness so far: 75600.0
#
# Generation 698
# Best fitness so far: 75600.0
#
# Generation 699
# Best fitness so far: 75600.0
#
# Generation 700
# Best fitness so far: 75600.0
#
# Generation 701
# Best fitness so far: 75600.0
#
# Generation 702
# Best fitness so far: 75600.0
#
# Generation 703
# Best fitness so far: 75600.0
#
# Generation 704
# Best fitness so far: 75600.0
#
# Generation 705
# Best fitness so far: 75600.0
#
# Generation 706
# Best fitness so far: 75600.0
#
# Generation 707
# Best fitness so far: 75600.0
#
# Generation 708
# Best fitness so far: 75600.0
#
# Generation 709
# Best fitness so far: 75600.0
#
# Generation 710
# Best fitness so far: 75600.0
#
# Generation 711
# Best fitness so far: 75600.0
#
# Generation 712
# Best fitness so far: 75600.0
#
# Generation 713
# Best fitness so far: 75600.0
#
# Generation 714
# Best fitness so far: 75600.0
#
# Generation 715
# Best fitness so far: 75600.0
#
# Generation 716
# Best fitness so far: 75600.0
#
# Generation 717
# Best fitness so far: 75600.0
#
# Generation 718
# Best fitness so far: 75600.0
#
# Generation 719
# Best fitness so far: 75600.0
#
# Generation 720
# Best fitness so far: 75600.0
#
# Generation 721
# Best fitness so far: 75600.0
#
# Generation 722
# Best fitness so far: 75600.0
#
# Generation 723
# Best fitness so far: 75600.0
#
# Generation 724
# Best fitness so far: 75600.0
#
# Generation 725
# Best fitness so far: 75600.0
#
# Generation 726
# Best fitness so far: 75600.0
#
# Generation 727
# Best fitness so far: 75600.0
#
# Generation 728
# Best fitness so far: 75600.0
#
# Generation 729
# Best fitness so far: 75600.0
#
# Generation 730
# Best fitness so far: 75600.0
#
# Generation 731
# Best fitness so far: 75600.0
#
# Generation 732
# Best fitness so far: 75600.0
#
# Generation 733
# Best fitness so far: 75600.0
#
# Generation 734
# Best fitness so far: 75600.0
#
# Generation 735
# Best fitness so far: 75600.0
#
# Generation 736
# Best fitness so far: 75600.0
#
# Generation 737
# Best fitness so far: 75600.0
#
# Generation 738
# Best fitness so far: 75600.0
#
# Generation 739
# Best fitness so far: 75600.0
#
# Generation 740
# Best fitness so far: 75600.0
#
# Generation 741
# Best fitness so far: 75600.0
#
# Generation 742
# Best fitness so far: 75600.0
#
# Generation 743
# Best fitness so far: 75600.0
#
# Generation 744
# Best fitness so far: 75600.0
#
# Generation 745
# Best fitness so far: 75600.0
#
# Generation 746
# Best fitness so far: 75600.0
#
# Generation 747
# Best fitness so far: 75600.0
#
# Generation 748
# Best fitness so far: 75600.0
#
# Generation 749
# Best fitness so far: 75600.0
#
# Generation 750
# Best fitness so far: 75600.0
#
# Generation 751
# Best fitness so far: 75600.0
#
# Generation 752
# Best fitness so far: 75600.0
#
# Generation 753
# Best fitness so far: 75600.0
#
# Generation 754
# Best fitness so far: 75600.0
#
# Generation 755
# Best fitness so far: 75600.0
#
# Generation 756
# Best fitness so far: 75600.0
#
# Generation 757
# Best fitness so far: 75600.0
#
# Generation 758
# Best fitness so far: 75600.0
#
# Generation 759
# Best fitness so far: 75600.0
#
# Generation 760
# Best fitness so far: 75600.0
#
# Generation 761
# Best fitness so far: 75900.0
#
# Generation 762
# Best fitness so far: 75900.0
#
# Generation 763
# Best fitness so far: 75900.0
#
# Generation 764
# Best fitness so far: 75900.0
#
# Generation 765
# Best fitness so far: 75900.0
#
# Generation 766
# Best fitness so far: 75900.0
#
# Generation 767
# Best fitness so far: 75900.0
#
# Generation 768
# Best fitness so far: 75900.0
#
# Generation 769
# Best fitness so far: 75900.0
#
# Generation 770
# Best fitness so far: 75900.0
#
# Generation 771
# Best fitness so far: 75900.0
#
# Generation 772
# Best fitness so far: 75900.0
#
# Generation 773
# Best fitness so far: 75900.0
#
# Generation 774
# Best fitness so far: 75900.0
#
# Generation 775
# Best fitness so far: 75900.0
#
# Generation 776
# Best fitness so far: 75900.0
#
# Generation 777
# Best fitness so far: 75900.0
#
# Generation 778
# Best fitness so far: 75900.0
#
# Generation 779
# Best fitness so far: 75900.0
#
# Generation 780
# Best fitness so far: 75900.0
#
# Generation 781
# Best fitness so far: 75900.0
#
# Generation 782
# Best fitness so far: 75900.0
#
# Generation 783
# Best fitness so far: 75900.0
#
# Generation 784
# Best fitness so far: 75900.0
#
# Generation 785
# Best fitness so far: 76000.0
#
# Generation 786
# Best fitness so far: 76000.0
#
# Generation 787
# Best fitness so far: 76000.0
#
# Generation 788
# Best fitness so far: 76000.0
#
# Generation 789
# Best fitness so far: 76000.0
#
# Generation 790
# Best fitness so far: 76000.0
#
# Generation 791
# Best fitness so far: 76000.0
#
# Generation 792
# Best fitness so far: 76000.0
#
# Generation 793
# Best fitness so far: 76000.0
#
# Generation 794
# Best fitness so far: 76000.0
#
# Generation 795
# Best fitness so far: 76000.0
#
# Generation 796
# Best fitness so far: 76000.0
#
# Generation 797
# Best fitness so far: 76000.0
#
# Generation 798
# Best fitness so far: 76000.0
#
# Generation 799
# Best fitness so far: 76000.0
#
# Generation 800
# Best fitness so far: 76000.0
#
# Generation 801
# Best fitness so far: 76000.0
#
# Generation 802
# Best fitness so far: 76000.0
#
# Generation 803
# Best fitness so far: 76000.0
#
# Generation 804
# Best fitness so far: 76000.0
#
# Generation 805
# Best fitness so far: 76000.0
#
# Generation 806
# Best fitness so far: 76000.0
#
# Generation 807
# Best fitness so far: 76000.0
#
# Generation 808
# Best fitness so far: 76000.0
#
# Generation 809
# Best fitness so far: 76000.0
#
# Generation 810
# Best fitness so far: 76000.0
#
# Generation 811
# Best fitness so far: 76000.0
#
# Generation 812
# Best fitness so far: 76000.0
#
# Generation 813
# Best fitness so far: 76000.0
#
# Generation 814
# Best fitness so far: 76000.0
#
# Generation 815
# Best fitness so far: 76000.0
#
# Generation 816
# Best fitness so far: 76000.0
#
# Generation 817
# Best fitness so far: 76000.0
#
# Generation 818
# Best fitness so far: 76000.0
#
# Generation 819
# Best fitness so far: 76000.0
#
# Generation 820
# Best fitness so far: 76000.0
#
# Generation 821
# Best fitness so far: 76000.0
#
# Generation 822
# Best fitness so far: 76000.0
#
# Generation 823
# Best fitness so far: 76000.0
#
# Generation 824
# Best fitness so far: 76000.0
#
# Generation 825
# Best fitness so far: 76000.0
#
# Generation 826
# Best fitness so far: 76000.0
#
# Generation 827
# Best fitness so far: 76000.0
#
# Generation 828
# Best fitness so far: 76000.0
#
# Generation 829
# Best fitness so far: 76000.0
#
# Generation 830
# Best fitness so far: 76000.0
#
# Generation 831
# Best fitness so far: 76000.0
#
# Generation 832
# Best fitness so far: 76000.0
#
# Generation 833
# Best fitness so far: 76000.0
#
# Generation 834
# Best fitness so far: 76000.0
#
# Generation 835
# Best fitness so far: 76000.0
#
# Generation 836
# Best fitness so far: 76000.0
#
# Generation 837
# Best fitness so far: 76000.0
#
# Generation 838
# Best fitness so far: 76000.0
#
# Generation 839
# Best fitness so far: 76000.0
#
# Generation 840
# Best fitness so far: 76000.0
#
# Generation 841
# Best fitness so far: 76000.0
#
# Generation 842
# Best fitness so far: 76000.0
#
# Generation 843
# Best fitness so far: 76000.0
#
# Generation 844
# Best fitness so far: 76000.0
#
# Generation 845
# Best fitness so far: 76000.0
#
# Generation 846
# Best fitness so far: 76000.0
#
# Generation 847
# Best fitness so far: 76000.0
#
# Generation 848
# Best fitness so far: 76000.0
#
# Generation 849
# Best fitness so far: 76000.0
#
# Generation 850
# Best fitness so far: 76000.0
#
# Generation 851
# Best fitness so far: 76000.0
#
# Generation 852
# Best fitness so far: 76000.0
#
# Generation 853
# Best fitness so far: 76000.0
#
# Generation 854
# Best fitness so far: 76000.0
#
# Generation 855
# Best fitness so far: 76000.0
#
# Generation 856
# Best fitness so far: 76000.0
#
# Generation 857
# Best fitness so far: 76000.0
#
# Generation 858
# Best fitness so far: 76000.0
#
# Generation 859
# Best fitness so far: 76000.0
#
# Generation 860
# Best fitness so far: 76000.0
#
# Generation 861
# Best fitness so far: 76000.0
#
# Generation 862
# Best fitness so far: 76000.0
#
# Generation 863
# Best fitness so far: 76000.0
#
# Generation 864
# Best fitness so far: 76000.0
#
# Generation 865
# Best fitness so far: 76000.0
#
# Generation 866
# Best fitness so far: 76000.0
#
# Generation 867
# Best fitness so far: 76000.0
#
# Generation 868
# Best fitness so far: 76000.0
#
# Generation 869
# Best fitness so far: 76000.0
#
# Generation 870
# Best fitness so far: 76000.0
#
# Generation 871
# Best fitness so far: 76000.0
#
# Generation 872
# Best fitness so far: 76000.0
#
# Generation 873
# Best fitness so far: 76000.0
#
# Generation 874
# Best fitness so far: 76000.0
#
# Generation 875
# Best fitness so far: 76000.0
#
# Generation 876
# Best fitness so far: 76000.0
#
# Generation 877
# Best fitness so far: 76000.0
#
# Generation 878
# Best fitness so far: 76000.0
#
# Generation 879
# Best fitness so far: 76000.0
#
# Generation 880
# Best fitness so far: 76000.0
#
# Generation 881
# Best fitness so far: 76000.0
#
# Generation 882
# Best fitness so far: 76000.0
#
# Generation 883
# Best fitness so far: 76000.0
#
# Generation 884
# Best fitness so far: 76000.0
#
# Generation 885
# Best fitness so far: 76000.0
#
# Generation 886
# Best fitness so far: 76000.0
#
# Generation 887
# Best fitness so far: 76000.0
#
# Generation 888
# Best fitness so far: 76000.0
#
# Generation 889
# Best fitness so far: 76000.0
#
# Generation 890
# Best fitness so far: 76000.0
#
# Generation 891
# Best fitness so far: 76000.0
#
# Generation 892
# Best fitness so far: 76000.0
#
# Generation 893
# Best fitness so far: 76000.0
#
# Generation 894
# Best fitness so far: 76000.0
#
# Generation 895
# Best fitness so far: 76000.0
#
# Generation 896
# Best fitness so far: 76000.0
#
# Generation 897
# Best fitness so far: 76000.0
#
# Generation 898
# Best fitness so far: 76000.0
#
# Generation 899
# Best fitness so far: 76000.0
#
# Generation 900
# Best fitness so far: 76000.0
#
# Generation 901
# Best fitness so far: 76000.0
#
# Generation 902
# Best fitness so far: 76000.0
#
# Generation 903
# Best fitness so far: 76000.0
#
# Generation 904
# Best fitness so far: 76000.0
#
# Generation 905
# Best fitness so far: 76000.0
#
# Generation 906
# Best fitness so far: 76000.0
#
# Generation 907
# Best fitness so far: 76000.0
#
# Generation 908
# Best fitness so far: 76000.0
#
# Generation 909
# Best fitness so far: 76000.0
#
# Generation 910
# Best fitness so far: 76000.0
#
# Generation 911
# Best fitness so far: 76000.0
#
# Generation 912
# Best fitness so far: 76000.0
#
# Generation 913
# Best fitness so far: 76000.0
#
# Generation 914
# Best fitness so far: 76000.0
#
# Generation 915
# Best fitness so far: 76000.0
#
# Generation 916
# Best fitness so far: 76000.0
#
# Generation 917
# Best fitness so far: 76000.0
#
# Generation 918
# Best fitness so far: 76000.0
#
# Generation 919
# Best fitness so far: 76000.0
#
# Generation 920
# Best fitness so far: 76000.0
#
# Generation 921
# Best fitness so far: 76000.0
#
# Generation 922
# Best fitness so far: 76000.0
#
# Generation 923
# Best fitness so far: 76000.0
#
# Generation 924
# Best fitness so far: 76000.0
#
# Generation 925
# Best fitness so far: 76000.0
#
# Generation 926
# Best fitness so far: 76000.0
#
# Generation 927
# Best fitness so far: 76000.0
#
# Generation 928
# Best fitness so far: 76000.0
#
# Generation 929
# Best fitness so far: 76000.0
#
# Generation 930
# Best fitness so far: 76000.0
#
# Generation 931
# Best fitness so far: 76000.0
#
# Generation 932
# Best fitness so far: 76000.0
#
# Generation 933
# Best fitness so far: 76000.0
#
# Generation 934
# Best fitness so far: 76400.0
#
# Generation 935
# Best fitness so far: 76400.0
#
# Generation 936
# Best fitness so far: 76400.0
#
# Generation 937
# Best fitness so far: 76400.0
#
# Generation 938
# Best fitness so far: 76400.0
#
# Generation 939
# Best fitness so far: 76400.0
#
# Generation 940
# Best fitness so far: 76400.0
#
# Generation 941
# Best fitness so far: 76400.0
#
# Generation 942
# Best fitness so far: 76400.0
#
# Generation 943
# Best fitness so far: 76400.0
#
# Generation 944
# Best fitness so far: 76400.0
#
# Generation 945
# Best fitness so far: 76400.0
#
# Generation 946
# Best fitness so far: 76400.0
#
# Generation 947
# Best fitness so far: 76400.0
#
# Generation 948
# Best fitness so far: 76400.0
#
# Generation 949
# Best fitness so far: 76400.0
#
# Generation 950
# Best fitness so far: 76400.0
#
# Generation 951
# Best fitness so far: 76400.0
#
# Generation 952
# Best fitness so far: 76400.0
#
# Generation 953
# Best fitness so far: 76400.0
#
# Generation 954
# Best fitness so far: 76400.0
#
# Generation 955
#
# Generation 1975
# Best fitness so far: 77600.0
#
# Generation 1976
# Best fitness so far: 77600.0
#
# Generation 1977
# Best fitness so far: 77600.0
#
# Generation 1978
# Best fitness so far: 77600.0
#
# Generation 1979
# Best fitness so far: 77600.0
#
# Generation 1980
# Best fitness so far: 77600.0
#
# Generation 1981
# Best fitness so far: 77600.0
#
# Generation 1982
# Best fitness so far: 77600.0
#
# Generation 1983
# Best fitness so far: 77600.0
#
# Generation 1984
# Best fitness so far: 77600.0
#
# Generation 1985
# Best fitness so far: 77600.0
#
# Generation 1986
# Best fitness so far: 77600.0
#
# Generation 1987
# Best fitness so far: 77600.0
#
# Generation 1988
# Best fitness so far: 77600.0
#
# Generation 1989
# Best fitness so far: 77600.0
#
# Generation 1990
# Best fitness so far: 77600.0
#
# Generation 1991
# Best fitness so far: 77600.0
#
# Generation 1992
# Best fitness so far: 77600.0
#
# Generation 1993
# Best fitness so far: 77600.0
#
# Generation 1994
# Best fitness so far: 77600.0
#
# Generation 1995
# Best fitness so far: 77600.0
#
# Generation 1996
# Best fitness so far: 77600.0
#
# Generation 1997
# Best fitness so far: 77600.0
#
# Generation 1998
# Best fitness so far: 77600.0
#
# Generation 1999
# Best fitness so far: 77600.0
#
# Generation 2000
# Best fitness so far: 77600.0
# Best fitness found: 77600.0

# %%
print("Best fitness found:", best.fitness())
print("\nTables:")

for i, table in enumerate(best.repr):
    print(f"Mesa {i+1}: {table}")
# Out:
# Best fitness found: 78700.0
#
# Tables:
# Mesa 1: [36, 0, 53, 43, 59, 37, 49, 1]
# Mesa 2: [51, 29, 28, 50, 24, 22, 23, 52]
# Mesa 3: [6, 25, 26, 56, 8, 7, 27, 57]
# Mesa 4: [33, 32, 48, 30, 21, 31, 34, 35]
# Mesa 5: [11, 9, 2, 10, 12, 13, 14, 3]
# Mesa 6: [39, 40, 42, 54, 55, 41, 44, 38]
# Mesa 7: [17, 19, 20, 5, 4, 18, 16, 15]
# Mesa 8: [46, 61, 62, 63, 47, 60, 58, 45]

# %%
for i in range(10):
    res = 0
    for j in range(10000):
        solution = WSSolution()
        res+=solution.fitness()
    res = res/10000
    print(f"Result {i+1}: Average Fitness: {res}")
# Out:
# Result 1: Average Fitness: 12228.75
# Result 2: Average Fitness: 12162.76
# Result 3: Average Fitness: 12224.06
# Result 4: Average Fitness: 12123.46
# Result 5: Average Fitness: 12217.69
# Result 6: Average Fitness: 12213.36
# Result 7: Average Fitness: 12225.02
# Result 8: Average Fitness: 12138.95
# Result 9: Average Fitness: 12215.36
# Result 10: Average Fitness: 12264.6

# %%
for i in range(3):
    res = 0
    scores = []
    for j in range(1000000):
        solution = WSSolution()
        res=solution.fitness()
        scores.append(res)
    avg_score = sum(scores)/1000000
    best_score = max(scores)
    print(f"Result {i+1}: Average Fitness {avg_score} and Best Fitness Found {best_score}")
# Out:
# Result 1: Average Fitness 12206.4644 and Best Fitness Found 35700.0
# Result 2: Average Fitness 12202.3834 and Best Fitness Found 33700.0
# Result 3: Average Fitness 12207.7375 and Best Fitness Found 33900.0
